# %% [markdown]
# # tests exploitation du package astrodm

# %%
import sys
# insérer le chemin suivant dans sys.path pour trouver le package astrodm et charger les outils
if 'D:\DOCUMENTS\Astronomie\dev' not in sys.path:
    sys.path.insert(0, 'D:\DOCUMENTS\Astronomie\dev')

# %%
# importer les outils de base
from astrodm import doublesOutils as do

# %%
# importer les outils de liste de programmes d'observations
from astrodm import doublesListeProgrammes as dlp

# %%
# importer le module de liste de réduction
from astrodm import doublesListeReductionsObservations as dlr

# %% [markdown]
# ## lister l'aide des fonctions de do

# %%
help(do)
# Out:
# Help on module astrodm.doublesOutils in astrodm:
#
# NAME
#     astrodm.doublesOutils - Created on Mon Nov 23 16:35:23 2020
#
# DESCRIPTION
#     @author: Dominique Martel
#     Produit un rapport des observations des mesures de séparation et
#     angle de position d'une paire d'étoiles doubles.
#
#     version 29
#
# FUNCTIONS
#     calculeMoyennes()
#
#     calculeObservations()
#
#     constantes()
#         Définition des constantes utilisées dans astrodm.
#          - Baader Planetarium Microguide : échelles ("/divE_mg2) de chaque instrumentation.
#          - Caméras : (à venir) modèles, échelle nominale, etc.
#
#         Returns
#         -------
#         None.
#
#     creeDateHeureLocal(dhl)
#
#     info_src_wds(src, paire, notes=True)
#         Fonction de recherche qui imprime les résultats de recherche dans le catalogue
#         WDS.
#
#         Parameters
#         ----------
#         src : TYPE src
#             La désignation de découvreur du système recherché.
# ...

# %%
# imprimer la liste des programmes
