# %% [markdown]
# # tests

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import sys
import os
# import du package astrodm
#if 'D:\DOCUMENTS\Astronomie\dev' not in sys.path:
sys.path.insert(0, 'D:\DOCUMENTS\Astronomie\dev')
from astrodm import doublesOutils as do

# %%
do.info_src_wds('stta254', '*', True) # True = imprimer les notes WDS.
# Out:
# Il y a 4 résultats pour «STTA254», paire = «*».
#
# Données tirées du Washington Double Stars Catalog (WDS)
# Tris sur "Disc" et "Comp"
# ------------------------------------------------------------------------------------------------------------------------
#    WDS       Disc  Comp Obs1 Obs2 pa1 pa2  sep1   sep2   mag1   mag2    DM    Notes n_RAJ2000   RAJ2000     DEJ2000
#                          yr   yr  deg deg arcsec arcsec  mag    mag                             "h:m:s"     "d:m:s"
# ---------- ------- ---- ---- ---- --- --- ------ ------ ------ ----- -------- ----- --------- ----------- -----------
# 00013+6021 STTA254   AB 1874 2018  90  89   58.9  57.80  7.400  8.33 +59 2810     N           00 01 15.85 +60 21 19.0
# 00013+6021 STTA254   AC 1879 2015 324 324  155.7 155.40  7.400  9.56 +59 2809     N           00 01 15.85 +60 21 19.0
# 00013+6021 STTA254   AD 1982 2016 118 118  182.0 181.40  7.400 10.35              N           00 01 15.85 +60 21 19.0
# 00013+6021 STTA254   BD 1879 2015 129 130  134.4 133.70  8.330 10.35 +59 2812     N           00 01 23.63 +60 21 19.6
# ------------------------------------------------------------------------------------------------------------------------
#
#  ***** WSD Notes pour STTA254 *****
#                  Text                 RefCode
# ------------------------------------- -------
# A is the semiregular variable WZ Cas.

# %%
do.reduction('complete', os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# C:\Users\DOMINI~1\AppData\Local\Temp/ipykernel_9856/2639508854.py in <module>
# ----> 1 do.reduction('complete', os.getcwd())
#
# D:\DOCUMENTS\Astronomie\dev\astrodm\doublesOutils.py in reduction(type_observation, cheminDeTeteProgramme)
#    1032          # par «STTA254» dans D:\DOCUMENTS\Astronomie\dev\STTA254\AB\P2021-023
#    1033
# -> 1034         sessions = DoubleSessions(typeObs=type_observation,\
#    1035                            chProg=cheminDeTeteProgramme)
#    1036
#
# D:\DOCUMENTS\Astronomie\dev\astrodm\doublesOutils.py in __init__(self, typeObs, chProg)
#     576         if typeObs == 'complete':
#     577             self.tobs = typeObs
# --> 578             self.systeme = Systeme(path.dirname(path.dirname(chProg)))
#     579
#     580             # nom de la paire
#
# D:\DOCUMENTS\Astronomie\dev\astrodm\doublesOutils.py in __init__(self, cheminSysteme)
#     551         # nom complet du fichier info système
#     552         self.ncfinfo_systeme =  cheminSysteme + '/' + self.nom + '_info_système.csv'
# --> 553         assert path.exists(self.ncfinfo_systeme), self.ncfinfo_systeme + ' non trouvé.'
#     554
#     555         # Pandas df du système
#
# AssertionError: D:\DOCUMENTS\Astronomie/Astronomie_info_système.csv non trouvé.
